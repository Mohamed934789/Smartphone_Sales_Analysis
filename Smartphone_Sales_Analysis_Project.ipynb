# %% [markdown]
# <div style="background-color:#2c3e50;padding:20px;border-radius:15px;text-align:center">
#   <h1 style="color:#ffffff;font-size:40px;margin:0;">📊 Smartphone Sales Data Analysis Dashboard</h1>
#   <p style="color:#ecf0f1;font-size:18px;margin-top:10px;">An End-to-End Exploratory Data Analysis Project using Python & Visualization Tools</p>
# </div>

# %% [markdown]
# # <span style="color: #2E86C1;">📊 Smartphone Sales Data Analysis Report</span>
#
# ## <span style="color: #117A65;">🔍 Introduction</span>
#
# This project aims to conduct a comprehensive data analysis on a dataset of **2,000 smartphones**, each with detailed attributes such as brand, specifications (RAM, Storage, Screen Size, Battery), pricing, user ratings, and sales performance (Revenue, Profit, Quantity Sold).
#
# The main goal is to extract **key business insights** that help understand performance trends, identify high-performing models or brands, and compare operating systems (Android vs iOS) in terms of profitability and user satisfaction.
#
# ---
#
# ## <span style="color: #D35400;">🛠️ Tools & Technologies Used</span>
#
# - **Python**: The core language used for data analysis.
# - **Pandas**: For data manipulation and cleaning.
# - **Matplotlib & Seaborn**: For creating beautiful and insightful visualizations.
# - **NumPy**: For numerical computations.
# - **Jupyter Notebook**: For interactive data exploration and presentation.
# - **Markdown + HTML**: For formatting and styling the report.
#
# ---
#
# ## <span style="color: #2980B9;">📦 Data Preprocessing Steps</span>
#
# Before diving into analysis, data cleaning and preparation were performed to ensure accuracy and consistency:
#
# - ✅ **Missing Values**:
#   - Missing `Profit` values were filled as **35% of the Sales_Revenue**.
#   - Rows with missing critical data like `Price_USD` or `Sales_Revenue` were **removed** to avoid skewed results.
# - ✅ **Consistency Checks**:
#   - Checked for unrealistic values (e.g., negative prices or sales).
#   - Verified no duplicate `Phone_ID`s.
#
# This preprocessing ensured that the dataset is **clean, reliable, and ready for analysis**.
#
# ---
#
# ## <span style="color: #117A65;">🎯 Key Performance Indicators (KPIs)</span>
#
# To measure smartphone performance, the following KPIs were calculated:
#
# 1. **Total Sales Revenue** – Sum of all revenue.
# 2. **Total Profit** – Total profit across all phones.
# 3. **Number of Units Sold per Brand** – Quantity sold by brand.
# 4. **Average Price per Brand** – Mean phone price for each brand.
# 5. **Top-Rated Phone** – Device with the highest rating.
# 6. **Average Rating per OS** – Comparison between Android and iOS.
# 7. **Most Profitable Phones** – Phones generating the highest profit.
# 8. **Average Profit per Unit Sold** – Insight into profit per phone sold.
# 9. **Android vs iOS Comparison** – Sales, revenue, and profit comparison between OSs.
#
# Each KPI was supported by **visualizations** and **statistical insights** to help stakeholders interpret the data more clearly.
#
# ---
#
# ## <span style="color: #8E44AD;">📈 Statistical & Visual Analysis</span>
#
# To enrich the analysis and move beyond raw numbers, several questions were explored using basic statistics and charts:
#
# - 📌 **Is there a correlation between RAM and sales?**
# - 📌 **Does battery size impact the number of units sold?**
# - 📌 **Do expensive phones tend to sell more or less?**
# - 📌 **How do user ratings vary across different operating systems?**
#
# Scatter plots and correlation metrics were used to answer these questions, backed by statistical observations.
#
# ---
#
# ## <span style="color: #E67E22;">🎨 Visualization Strategy</span>
#
# A set of well-structured and clearly labeled visualizations were used to present findings:
#
# - **Bar charts**: Sales per brand, profit per brand, OS comparisons
# - **Scatter plots**: RAM vs sales, battery vs sales, price vs rating
# - **Pie charts** : Brand distribution or OS market share
#
# These visuals enhance understanding and allow **quick interpretation** of large datasets.
#
# ---
#
# ## <span style="color: #7D3C98;">✅ Conclusion</span>
#
# This report provides actionable insights on smartphone sales and performance using data analysis. It demonstrates:
#
# - How data cleaning ensures reliability.
# - The importance of choosing the right KPIs.
# - How visual analytics helps stakeholders make better decisions.
#
# By combining Python, Pandas, visual tools, and domain understanding, the project delivers a clear overview of the smartphone market based on the provided dataset.
#
# ---

# %% [markdown]
# <div style="background-color:#2c3e50;padding:10px;border-radius:10px">
#   <h3 style="color:white;">🔧 Step 1: Import Libraries & Load Dataset</h3>
# </div>

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\IT SHOP\Downloads\smartphone_sales_dataset.csv')

# %%
df.head()
# Out:
#    Phone_ID    Brand  RAM_GB  Storage_GB  Screen_Size  Price_USD  Battery_mAh  \
# 0         1  OnePlus       8         256         7.15      395.0       3227.0
# 1         2   Google      12         256         6.44      228.0       5881.0
# 2         3   Xiaomi      16        1024         7.23      905.0       3857.0
# 3         4   Google      16         512         6.49        NaN       4268.0
# 4         5   Google      16         128         7.03        NaN       5865.0
#
#         OS  Rating  Quantity_Sold  Sales_Revenue    Profit
# 0  Android     4.3             66        26070.0    6517.5
# 1  Android     3.5            100        22800.0    5700.0
# 2      iOS     4.8            496            NaN  112220.0
# 3      iOS     4.7            319       389180.0   97295.0
# 4  Android     4.0            364        78260.0       NaN

# %% [markdown]
# <div style="background-color:#34495e;padding:10px;border-radius:10px">
#   <h3 style="color:white;">🧹 Step 2: Data Cleaning & Handling Missing Values</h3>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Phone_ID       2000 non-null   int64
#  1   Brand          2000 non-null   object
#  2   RAM_GB         2000 non-null   int64
#  3   Storage_GB     2000 non-null   int64
#  4   Screen_Size    2000 non-null   float64
#  5   Price_USD      1900 non-null   float64
#  6   Battery_mAh    1940 non-null   float64
#  7   OS             2000 non-null   object
#  8   Rating         2000 non-null   float64
#  9   Quantity_Sold  2000 non-null   int64
#  10  Sales_Revenue  1900 non-null   float64
#  11  Profit         1940 non-null   float64
# dtypes: float64(6), int64(4), object(2)
# memory usage: 187.6+ KB

# %%
df.describe()
# Out:
#           Phone_ID       RAM_GB   Storage_GB  Screen_Size    Price_USD  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  1900.000000
# mean   1000.500000     9.365000   400.704000     6.248115   865.379474
# std     577.494589     4.340529   349.657974     0.724035   371.094769
# min       1.000000     4.000000    64.000000     5.000000   200.000000
# 25%     500.750000     6.000000   128.000000     5.620000   554.750000
# 50%    1000.500000     8.000000   256.000000     6.230000   867.000000
# 75%    1500.250000    12.000000   512.000000     6.882500  1188.000000
# max    2000.000000    16.000000  1024.000000     7.500000  1499.000000
#
#        Battery_mAh       Rating  Quantity_Sold  Sales_Revenue         Profit
# count  1940.000000  2000.000000    2000.000000    1900.000000    1940.000000
# mean   4516.403608     3.997550     274.252000  236156.022632   59261.837629
# std     863.964791     0.578737     128.769369  155732.533037   38988.862100
# ...

# %%
df.isnull().sum()
# Out:
# Phone_ID           0
# Brand              0
# RAM_GB             0
# Storage_GB         0
# Screen_Size        0
# Price_USD        100
# Battery_mAh       60
# OS                 0
# Rating             0
# Quantity_Sold      0
# Sales_Revenue    100
# Profit            60
# dtype: int64

# %%
df=df.dropna(subset=['Price_USD'])

# %%
df["Battery_mAh"].fillna(df["Battery_mAh"].mean(), inplace=True)
# Out:
# C:\Users\IT SHOP\AppData\Local\Temp\ipykernel_24504\2874878717.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Battery_mAh"].fillna(df["Battery_mAh"].mean(), inplace=True)

# %%
df["Profit"].fillna(df["Sales_Revenue"] * 0.35,inplace=True)
# Out:
# C:\Users\IT SHOP\AppData\Local\Temp\ipykernel_24504\3770020362.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Profit"].fillna(df["Sales_Revenue"] * 0.35,inplace=True)

# %%
df.isnull().sum()
# Out:
# Phone_ID          0
# Brand             0
# RAM_GB            0
# Storage_GB        0
# Screen_Size       0
# Price_USD         0
# Battery_mAh       0
# OS                0
# Rating            0
# Quantity_Sold     0
# Sales_Revenue    96
# Profit            4
# dtype: int64

# %%
df["Sales_Revenue"] = df["Sales_Revenue"].fillna(df["Price_USD"] * df["Quantity_Sold"])

# %%
df.isnull().sum()
# Out:
# Phone_ID         0
# Brand            0
# RAM_GB           0
# Storage_GB       0
# Screen_Size      0
# Price_USD        0
# Battery_mAh      0
# OS               0
# Rating           0
# Quantity_Sold    0
# Sales_Revenue    0
# Profit           4
# dtype: int64

# %%
df["Profit"] = df["Profit"].fillna(df["Sales_Revenue"] * 0.35)

# %%
df.isnull().sum()
# Out:
# Phone_ID         0
# Brand            0
# RAM_GB           0
# Storage_GB       0
# Screen_Size      0
# Price_USD        0
# Battery_mAh      0
# OS               0
# Rating           0
# Quantity_Sold    0
# Sales_Revenue    0
# Profit           0
# dtype: int64

# %% [markdown]
# <div style="background-color:#1abc9c;padding:10px;border-radius:10px">
#                         <h3 style="color:white;">                   ✅ Data is Now Clean & Ready for Analysis              </h3>
# </div>

# %% [markdown]
# <div style="background-color:#3498db;padding:10px;border-radius:10px">
#   <h3 style="color:white;">💰 Total Sales Revenue and Total Profit</h3>
# </div>

# %%
total_revenue = df["Sales_Revenue"].sum()
total_profit = df["Profit"].sum()

# %%
print(f"🔹 Total Sales Revenue: {total_revenue}")
print(f"🔹 Total Profit: {total_profit}")
# Out:
# 🔹 Total Sales Revenue: 448641629.0
# 🔹 Total Profit: 113313427.94999999

# %%
labels = ['Total Sales Revenue', 'Total Profit']
values = [total_revenue, total_profit]

plt.figure(figsize=(6, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, colors=["#4CAF50", "#2196F3"])
plt.title('Sales Revenue vs Profit')
plt.show()

# %% [markdown]
# <div style="background-color:#9b59b6;padding:10px;border-radius:10px">
#   <h3 style="color:white;">📦 Units Sold per Brand</h3>
# </div>

# %%
units_sold_per_brand = df.groupby("Brand")["Quantity_Sold"].sum()

# %%
units_sold_per_brand
# Out:
# Brand
# Apple      82593
# Google     86078
# Huawei     87954
# OnePlus    87792
# Samsung    91492
# Xiaomi     84949
# Name: Quantity_Sold, dtype: int64

# %%
plt.figure(figsize=(10, 6))
units_sold_per_brand.plot(kind='bar', color='skyblue')
plt.title('Number of Units Sold per Brand')
plt.xlabel('Brand')
plt.ylabel('Units Sold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="background-color:#e74c3c;padding:10px;border-radius:10px">
#   <h3 style="color:white;">⭐ Top-Rated Phone</h3>
# </div>

# %%
top_rated_phone = df[df["Rating"] == df["Rating"].max()]
top_rated_phone[['Phone_ID', 'Brand','Rating']]
# Out:
#       Phone_ID    Brand  Rating
# 63          64   Huawei     5.0
# 86          87  Samsung     5.0
# 87          88   Huawei     5.0
# 163        164   Huawei     5.0
# 223        224  Samsung     5.0
# 314        315  Samsung     5.0
# 418        419   Huawei     5.0
# 424        425  Samsung     5.0
# 466        467  Samsung     5.0
# 522        523   Xiaomi     5.0
# 603        604   Google     5.0
# 607        608  Samsung     5.0
# 691        692  OnePlus     5.0
# 715        716  OnePlus     5.0
# 887        888   Huawei     5.0
# 916        917  Samsung     5.0
# 958        959  Samsung     5.0
# 996        997   Google     5.0
# 1013      1014   Google     5.0
# 1047      1048    Apple     5.0
# 1079      1080   Huawei     5.0
# 1120      1121  Samsung     5.0
# 1211      1212   Xiaomi     5.0
# 1261      1262  Samsung     5.0
# 1418      1419    Apple     5.0
# 1474      1475   Huawei     5.0
# 1498      1499   Xiaomi     5.0
# 1509      1510   Google     5.0
# ...

# %% [markdown]
# <div style="background-color:#16a085;padding:15px;border-radius:10px;text-align:center">
#   <h2 style="color:white;font-size:32px;margin:0;">1. Which brand sold the most phones?</h2>
# </div>

# %%
df.groupby('Brand')['Quantity_Sold'].sum().sort_values(ascending=False)
# Out:
# Brand
# Samsung    91492
# Huawei     87954
# OnePlus    87792
# Google     86078
# Xiaomi     84949
# Apple      82593
# Name: Quantity_Sold, dtype: int64

# %% [markdown]
# <div style="background-color:#27ae60;padding:15px;border-radius:10px;text-align:center">
#   <h2 style="color:white;font-size:32px;margin:0;">2. Which brand made the most profit?</h2>
# </div>

# %%
most_profitable_phones = df.sort_values(by="Profit", ascending=False)
most_profitable_phones[['Phone_ID', 'Brand', 'Profit']].head()
# Out:
#       Phone_ID    Brand     Profit
# 1581      1582   Google  194780.25
# 1079      1080   Huawei  184628.50
# 1874      1875  Samsung  183264.00
# 530        531   Google  183112.30
# 1667      1668   Google  179328.75

# %%
plt.figure(figsize=(10, 6))
most_profitable_phones.head(10).plot(kind='bar', x='Brand', y='Profit', color='purple')
plt.title('Top 10 Most Profitable Phones')
plt.xlabel('Phone Model')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#f39c12;padding:15px;border-radius:10px;text-align:center">
#   <h2 style="color:white;font-size:32px;margin:0;">3. Is there a relationship between RAM and sales?</h2>
# </div>

# %%
df[['RAM_GB', 'Quantity_Sold']].corr()
# Out:
#                  RAM_GB  Quantity_Sold
# RAM_GB         1.000000       0.015309
# Quantity_Sold  0.015309       1.000000

# %%
sns.scatterplot(data=df, x='RAM_GB', y='Quantity_Sold')
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Quantity_Sold'>

# %% [markdown]
# <div style="background-color:#e67e22;padding:15px;border-radius:10px;text-align:center">
#   <h2 style="color:white;font-size:32px;margin:0;">4. Does battery size affect sales?</h2>
# </div>

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Battery_mAh'], df['Quantity_Sold'], color='teal')
plt.title('Battery Capacity vs Units Sold')
plt.xlabel('Battery Capacity (mAh)')
plt.ylabel('Quantity Sold')
plt.show()

# %% [markdown]
# <div style="background-color:#2980b9;padding:15px;border-radius:10px;text-align:center">
#   <h2 style="color:white;font-size:32px;margin:0;">5. Which OS has the higher average rating – Android or iOS?</h2>
# </div>

# %%
avg_rating_per_os = df.groupby("OS")["Rating"].mean()
avg_rating_per_os
# Out:
# OS
# Android    3.994737
# iOS        4.014551
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(6, 6))
avg_rating_per_os.plot(kind='bar', color=['green', 'orange'])
plt.title('Average Rating per OS')
plt.xlabel('Operating System')
plt.ylabel('Average Rating')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#9b59b6;padding:15px;border-radius:10px;text-align:center">
#   <h2 style="color:white;font-size:32px;margin:0;">6. Do higher-priced phones sell more?</h2>
# </div>

# %%
plt.figure(figsize=(8,8))
plt.scatter(x=df['Price_USD'],y=df['Quantity_Sold'],color='teal')
plt.ylabel('Quantity_Sold')
plt.xlabel('Price_USD')
plt.title('Price_USD vs Units Sold')
plt.show()

# %% [markdown]
# <div style="background-color:#34495e;padding:10px;border-radius:10px">
#   <h3 style="color:white;">📊 Average Profit per Unit Sold</h3>
# </div>

# %%
df['Avg_Profit_per_Unit'] = df['Profit'] / df['Quantity_Sold']
avg_profit_per_unit = df['Avg_Profit_per_Unit'].mean()
avg_profit_per_unit
# Out:
# np.float64(218.8540789473684)

# %% [markdown]
# <div style="background-color:#8e44ad;padding:10px;border-radius:10px">
#   <h3 style="color:white;">🤖📱 Android vs iOS: Revenue, Profit & Sales</h3>
# </div>

# %%
os_comparison = df.groupby("OS")[["Sales_Revenue", "Profit", "Quantity_Sold"]].sum()
os_comparison
# Out:
#          Sales_Revenue       Profit  Quantity_Sold
# OS
# Android    375492459.0  94849067.55         434538
# iOS         73149170.0  18464360.40          86320

# %%
os_comparison.plot(kind='bar', figsize=(10, 6), color=['#FF5722', '#4CAF50'])
plt.title('Android vs iOS: Revenue, Profit, Sales')
plt.xlabel('Operating System')
plt.ylabel('Amount')
plt.xticks(rotation=0)

plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Rating'], df['Quantity_Sold'], color='purple')
plt.title('Rating vs Quantity Sold')
plt.xlabel('Rating')
plt.ylabel('Quantity Sold')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#16a085;padding:10px;border-radius:10px">
#   <h3 style="color:white;">🧾 Final Conclusion</h3>
# </div>

# %% [markdown]
# - In this project, we performed a complete data analysis of smartphone sales using a dataset of 2000 phones.
# - We started by cleaning the data: handling missing values for `Profit`, `Price_USD`, and `Sales_Revenue`, as instructed.
# - We calculated multiple **Key Performance Indicators (KPIs)** such as:
#   - ✅ Total Sales Revenue
#   - ✅ Total Profit
#   - ✅ Units Sold per Brand
#   - ✅ Average Price per Brand
#   - ✅ Top-Rated Phone
#   - ✅ Average Rating per OS
#   - ✅ Most Profitable Phones
#   - ✅ Average Profit per Unit Sold
#   - ✅ Comparison between Android & iOS in terms of Revenue, Profit, and Sales.
#
# - Using data visualization tools like **Matplotlib** and **Seaborn**, we created clean and informative charts that made insights easier to understand.
# - From our analysis, we noticed key trends like:
#   - Some brands have high unit sales but low profits, and vice versa.
#   - iOS devices generally have higher prices and ratings, but Android sells more units overall.
#   - There's a weak correlation between battery size or RAM and sales, which suggests consumers may care more about brand and price.
#
# 🎯 Overall, the project helped us understand which phones perform better in the market, and what features may influence sales, price, and profit. This kind of analysis is useful for smartphone companies to make better decisions.
